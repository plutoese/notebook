# %% [markdown]
# ## Probability Distribution

# %%
# 设置图片格式
options(repr.plot.width=4, repr.plot.height=4)

# %% [markdown]
# ### Binomial distribution

# %%
N <- 1000
n <- 10
p <- .5
x <- rbinom(N,n,p)
hist(x, 
     xlim = c(min(x), max(x)), 
     probability = TRUE, 
     nclass = max(x) - min(x) + 1, 
     col = 'lightblue',
     main = 'Binomial distribution, n=10, p=.5')
lines(density(x, bw=1), col = 'red', lwd = 3)
# Out:
# Plot with title "Binomial distribution, n=10, p=.5"

# %%
N <- 100000
n <- 100
p <- .5
x <- rbinom(N,n,p)
hist(x, 
     xlim = c(min(x), max(x)), 
     probability = TRUE, 
     nclass = max(x) - min(x) + 1, 
     col = 'lightblue',
     main = 'Binomial distribution, n=100, p=.5')
lines(density(x,bw=1), col = 'red', lwd = 3)
# Out:
# Plot with title "Binomial distribution, n=100, p=.5"

# %%
p <- .9
x <- rbinom(N,n,p)
hist(x, 
     xlim = c(min(x), max(x)), 
     probability = TRUE, 
     nclass = max(x) - min(x) + 1, 
     col = 'lightblue',
     main = 'Binomial distribution, n=100, p=.9')
lines(density(x,bw=1), col = 'red', lwd = 3)
# Out:
# Plot with title "Binomial distribution, n=100, p=.9"

# %% [markdown]
# ### Hypergeometric distribution

# %%
N <- 10000
n <- 5
x <- rhyper(N, 15, 5, 5)
hist(x, 
     xlim=c(min(x),max(x)), probability=T, nclass=max(x)-min(x)+1, 
     col='lightblue',
     main='Hypergeometric distribution, n=20, p=.75, k=5')
lines(density(x,bw=1), col='red', lwd=3)
# Out:
# Plot with title "Hypergeometric distribution, n=20, p=.75, k=5"

# %%
N <- 10000
n <- 5
x <- rhyper(N, 300, 100, 100)
hist(x, 
     xlim=c(min(x),max(x)), probability=T, nclass=max(x)-min(x)+1, 
     col='lightblue',
     main='Hypergeometric distribution, n=400, p=.75, k=100')
lines(density(x,bw=1), col='red', lwd=3)
# Out:
# Plot with title "Hypergeometric distribution, n=400, p=.75, k=100"

# %% [markdown]
# ### Poisson distribution

# %%
N <- 10000
x <- rpois(N, 3)
hist(x, 
     xlim=c(min(x),max(x)), probability=T, nclass=max(x)-min(x)+1, 
     col='lightblue',
     main='Poisson distribution, lambda=3')
lines(density(x,bw=1), col='red', lwd=3)
# Out:
# Plot with title "Poisson distribution, lambda=3"

# %%
N <- 10000
x <- rpois(N, 5)
hist(x, 
     xlim=c(min(x),max(x)), probability=T, nclass=max(x)-min(x)+1, 
     col='lightblue',
     main='Poisson distribution, lambda=5')
lines(density(x,bw=1), col='red', lwd=3)
# Out:
# Plot with title "Poisson distribution, lambda=5"

# %%
N <- 10000
x <- rpois(N, 20)
hist(x, 
     xlim=c(min(x),max(x)), probability=T, nclass=max(x)-min(x)+1, 
     col='lightblue',
     main='Poisson distribution, lambda=20')
lines(density(x,bw=1), col='red', lwd=3)
# Out:
# Plot with title "Poisson distribution, lambda=20"

# %% [markdown]
# ### Normal Distribution

# %%
limite.centrale <- function (r=runif, m=.5, s=1/sqrt(12), n=c(1,3,10,30), N=1000) {
  for (i in n) {
    x <- matrix(r(i*N),nc=i)
    x <- ( apply(x, 1, sum) - i*m )/(sqrt(i)*s)
    hist(x, col='light blue', probability=T, main=paste("n =",i), 
         ylim=c(0,max(.4, density(x)$y)))
    lines(density(x), col='red', lwd=3)
    curve(dnorm(x), col='blue', lwd=3, lty=3, add=T)
    if( N>100 ) {
      rug(sample(x,100))
    } else {
      rug(x)
    }
  }
}
op <- par(mfrow=c(2,2))
limite.centrale()
par(op)
# Out:
# Plot with title "n = 30"

# %%
curve(dnorm(x), xlim=c(-3,3), col='red', lwd=3)
title(main='Normal Probability Distribution Function')
# Out:
# Plot with title "Normal Probability Distribution Function"

# %% [markdown]
# ### Student's T

# %%
# 设置图片格式
options(repr.plot.width=5, repr.plot.height=5)

curve( dt(x,1), xlim=c(-3,3), ylim=c(0,.4), col='red', lwd=2 )
curve( dt(x,2), add=T, col='blue', lwd=2 )
curve( dt(x,5), add=T, col='green', lwd=2 )
curve( dt(x,10), add=T, col='orange', lwd=2 )
curve( dnorm(x), add=T, lwd=3, lty=3 )
title(main="Student T distributions")
legend(par('usr')[2], par('usr')[4], xjust=1,
       c('df=1', 'df=2', 'df=5', 'df=10', 'Gaussian distribution'),
       lwd=c(2,2,2,2,2), 
       lty=c(1,1,1,1,3),
       col=c('red', 'blue', 'green', 'orange', par("fg")))
# Out:
# Plot with title "Student T distributions"
