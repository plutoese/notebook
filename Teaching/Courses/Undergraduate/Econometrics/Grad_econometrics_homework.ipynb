# %% [markdown]
# ## 研究生计量经济学练习题
# ---

# %% [markdown]
# 1.考虑回归模型$y=\beta_{0}+\beta_{1}x+u$
#
# (1) 设$\beta_{0}=0$，推导$\beta_{1}$的最小二乘估计量公式
#
# (2) 设$\beta_{1}=0$，推导$\beta_{0}$的极大似然估计量公式
#
# <br>
#
# 2.q阶移动平均过程具有形式
#
# $$Y_{t}=\beta_{0}+e_{t}+b_{1}e_{t-1}+b_{2}e_{t-2}+\dots+b_{q}e_{t-q}$$
#
# 其中$e_{t}$是均值为0，方差为$\sigma^{2}_{e}$，序列不相关的随机变量
#
# （1）证明：$E(Y_{t})=\beta_{0}$
#
# （2）证明：$Y_{t}$的方差为$Var(Y_{t})=\sigma^{2}_{e}(1+b_{1}^{2}+b_{2}^{2}+\dots+b_{q}^{2})$
#
# （3）设$q=1$。推导$Y$的自协方差和自相关系数
#
# <br>
#
# 3.请阐述动态面板数据模型为什么不能用固定效应估计量和随机效应估计量。
#
# <br>
#
# 4.案例分析：我国贫困地区中小学寄宿生的营养不良问题十分严重，亟须及时制定相应政策进行营养干预。但是，营养干预政策能否收到显著成效呢？为了考察通过校园餐对贫困地区学龄儿童进行营养干预的效果，探索营养干预的操作机制，2007年，中国发展基金会（简称CDRF）启动了“贫困地区寄宿制小学学生营养改善项目”。该项目选择了河北省的崇礼县进行研究。CDRF在河北崇礼县选取了10所寄宿制小学进行实验。每个县进入项目的小学都是从经济条件十分接近的乡中选取的，以保证学校之间的可比性。这些学校被分为处理组和对照组。项目组分别搜集了项目实施前后学生人力资本发展的变量（humancapital）及其他一些控制变量。现项目组需要评估通过校园餐进行的营养干预对贫困地区寄宿生人力资本发展的影响，请你设计一个实验方案，对此项目进行评估。
#
# <br>
#
# 5.研究者用实证方法考察了地区的执法水平对金融发展的影响。他用面板数据设定了下列实证模型
# $$Loan_{it}=\beta_{0}+\beta_{1} law_{it}+\beta_{2} X_{it}+\operatorname{Pr}ov_{i}+\text { Year }_{t}+u_{it}$$
#
# 其中loan是信贷相对规模，关键变量law是一个地区的执法水平，控制变量共有5个，分别是固定资产投资中国有经济占比(State_FI)，反映当地经济的国有化程度；财政支出占GDP比重(Exp)，反映地方政府对经济的干预能力；高等院校在校生总数占常住人口比重(Edu)，反映当地的人力资本状况；总就业人口( Employ，万人)；居民消费价格指数（CPI），即通货膨胀率，Prov是省区固定效应，Year 是年度固定效应。首先，他用OLS进行估计，得到的结果见表1。考虑到可能存在的内生性问题，因此尝试了工具变量。研究发现各省政法委书记受法律教育的情况（Sec_edu）是能较好地充当执法水平工具变量的因素。因此，利用工具变量，该研究者又用2SLS进行估计，其中第一阶段和最终结果见表2和表3。请回答下列问题：
#
# （a）请计算表1回归模型（2）中变量Law的系数的t值
# （b）请解释表1回归模型（1）的结果
# （b）请说明这里存在的内生性问题是指什么？
# （c）请具体说明Sec_edu用作工具变量要符合哪两个条件？请说明该工具变量是否符合了这两个条件
# （d）请说明2SLS估计的步骤，请评估在这个实证中你更偏好OLS还是2SLS的实证结果。
#
# <div align=center>
# <img src="./pic/w024.jpg" width = "50%" />
# </div>
#
# <div align=center>
# <img src="./pic/w025.jpg" width = "50%" />
# </div>
#
# <div align=center>
# <img src="./pic/w026.jpg" width = "50%" />
# </div>
