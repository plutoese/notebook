# %% [markdown]
# # Stable matchings

# %% [markdown]
# ## The formal (cooperative) model
#
# **Marriage Problem**
#
# The elements of the formal model are as follows.
# 婚姻匹配模型的基本结构如下
#
# - **Men and Women**
# 男性和女性
#
# There are two finite and disjoint sets $M$ and $W$: $M=\left\{m_{1}, m_{2}, \dots, m_{n}\right\}$ is the set of men, and $W=\left\{w_{1}, w_{2}, \dots, w_{p}\right\}$ is the set of women.
#
# 男性和女性用不相交的两个集合表示。
#
# <br>
#
# - **Preference**
# 偏好
#
# Each man has preferences over the women, and each woman has preferences over the men.
# 他们分别对异性具有偏好。
#
# These preferences may be such that, say, a man $m$ would prefer to remain single rather than be married to some woman $w$ he doesn't care for.
# 当然他（她）也可以更偏好单身。
#
# An individual's preferences are meant to represent how he or she would choose among different alternatives, if he or she were faced with a choice.
# 个体偏好代表了他（她）在面临选择时会如何进行抉择。
#
# when we say some individual **prefers alternative a to alternative b**, we mean that if that individual were faced with a choice between the two, he or she would choose a and not b, and if faced with a choice from a set of alternatives that included b, then he or she would not choose b if a were also available.
# 定义偏好$a$甚于$b$，在于面临两者的选择时，会选择$a$而非$b$。
#
# When we say an individual is **indifferent between the two**, we mean that he or she might choose either one.
# 定义无差异偏好。
#
# We will say an individual **likes $a$ at least as well as $b$** if he or she either prefers $a$ to $b$ or is indifferent between them.
# 定义喜欢$a$至少和喜欢$b$一样多。
#
# <br>
#
# **数学表达**
#
# To express these preferences concisely, the preferences of each man $m$ will be represented by **an ordered list of preferences**, $P(m)$, on the set $W \cup\{m\}$.
#
# A man $m$'s preferences might be of the form
#
# $$P(m)=w_{1}, w_{2}, m, w_{3}, \dots, w_{p}$$
#
# indicating that his first choice is to be married to woman $w_{1}$ his second choice is to be married to woman $w_{2}$, and his third choice is to remain single.
#
# 这意味着他的第一选择是和$w_{1}$结婚，第二选择是和和$w_{2}$结婚，第三选择是保持单身。
#
# A man $m$' may be indifferent between several possible mates. This will be denoted by brackets in the preference list, so for example the list
#
# $$P\left(m^{\prime}\right)=w_{2},\left[w_{1}, w_{7}\right], m^{\prime}, w_{3}, \dots, w_{k}$$
#
# indicates that man $m$' prefers woman $w_{2}$ to wu but that he is indifferent between $w_{1}$ and $w_{7}$, and he prefers remaining single to marrying anyone else.
#
# 无差异的数学表达用方括号。
#
# We will usually describe an agent's preferences by writing only the ordered set of people that the agent prefers to being single. Thus the preferences $P(m)$ just described will be abbreviated by 只需列出偏好在单身之前的对象有序列表即可
#
# $$P(m)=w_{1}, w_{2}$$
#
# <br>
#
# We will usually describe an agent's preferences by We will denote by $P$ the set of preference lists $\boldsymbol{P}=\left\{P\left(m_{1}\right), \ldots, P\left(m_{n}\right), P\left(w_{1}\right), \ldots, P\left(w_{p}\right)\right\}$, one for each man and woman. 用$P$来表示有序偏好列表
#
# A specific marriage market will be denoted by the triple $(M, W ; P)$. We write $\boldsymbol{w}>_{m} \boldsymbol{w}^{\prime}$ to mean $m$ prefers $w$ to $w^{\prime}$, and $\boldsymbol{w} \geq_{m} \boldsymbol{w}^{\prime}$ to mean $m$ likes $w$ at least as well as $w^{\prime}$. Similarly we write $m>_{w} m^{\prime}$ and $m \geq_{w} m^{\prime}$. Woman $w$ is acceptable to man $m$ if he likes her at least as well as remaining single, that is, if $\boldsymbol{w} \geq_{m} m$. Analogously, $m$ is acceptable to $w$ if $m \geq_{w} \boldsymbol{w}$. If an individual is not indifferent between any two acceptable alternatives, he or she has **strict preferences**.
# 基本的术语
#
# Economists customarily make two assumptions about the preferences:
#
# - The first is that these preferences form a **complete ordering**. This means that any two alternatives can be compared - the individual may be indifferent between them, but he is never confronted with a choice he is unable to make.
#
# - The second is that the preferences are **transitive**, which means that if $a$ is liked at least as well as $b$, and if $b$ is liked at least as well as $c$, then $a$ is liked at least as well as $c$.
#
# 关于偏好的两个假定，（1）完全排序；（2）传递性
#
# Individuals whose preferences possess these two properties are called **rational**.
# 理性意味着符合上述两个假定。如果不符合，那么可能会有money pump的情况出现
#
# It would be sufficient to make only the weaker assumption that preferences are **acyclic**, that is, that cycles (e.g., a>mb>mOma) of any length will not occur.
# 非循环性
#
# <br>
#
# **Definition 2.1.**
#
# A **matching** $\mu$ is a one-to-one correspondence from the set $M \cup W$ onto itself of order two (that is, $\mu^{2}(x)=x$) such that if $\mu(m) \neq m$ then $\mu(m) \in W$ and if $\mu(w) \neq w$ then $\mu(w) \in M$. We refer to $\mu(x)$ as the mate of $x$.
#
# Note that $\mu^{2}(x)=x$ means that if man $m$ is matched to woman $w$ (i.e., if $\mu(m)=w$) then woman $w$ is matched to man $m$ (i.e., $\mu(w)=m$)
#
# The definition also requires that individuals who are not single be matched with agents of the opposite set - that is, men are matched with women. These two requirements explain why matchings can be thought of as sets of marriages
#
# <br>
#
# A matching will sometimes be represented as a set of matched pairs. Thus, for example, the matching
#
# $$\mu=\begin{array}{llll}{w_{4}} & {w_{1}} & {w_{2}} & {w_{3}} & {\left(m_{5}\right)} \\ {m_{1}} & {m_{2}} & {m_{3}} & {m_{4}} & {m_{5}}\end{array}$$

# %% [markdown]
# ## Stable matchings - a theoretical framework
#
# We can now start to consider the elements of a theory about **which matchings are likely to occur, and which are not**. This is where the **rules of the game play a critical role**.
# 讨论什么样的匹配能发生，什么样的匹配不太可能发生。在这其中，规则发挥了重要的作用。
#
# <br>
#
# **Definition 2.2.**
#
# The matching $\mu$ is **individually rational** if each agent is acceptable to his or her mate. That is, a matching is individually rational if it is not blocked by any (individual) agent.
#
# **Definition 2.3. **
#
# A matching fi is **stable** if it is not blocked by any individual or any pair of agents.
# 稳定匹配的定义。
#
#
# **Example 2.4**
#
# There are three men and three women, with the following preferences.
#
# $$\begin{array}{ll}{P\left(m_{1}\right)=w_{2}, w_{1}, w_{3}} & {P\left(w_{1}\right)=m_{1}, m_{3}, m_{2}} \\ {P\left(m_{2}\right)=w_{1}, w_{3}, w_{2}} & {P\left(w_{2}\right)=m_{3}, m_{1}, m_{2}} \\ {P\left(m_{3}\right)=w_{1}, w_{2}, w_{3}} & {P\left(w_{3}\right)=m_{1}, m_{3}, m_{2}}\end{array}$$
#
# All possible matchings are individually rational (since all pairs $$ are mutually acceptable). The matching $\mu$ given by
#
# $$\mu=\begin{array}{ll}{w_{1}} & {w_{2}} & {w_{3}} \\ {m_{1}} & {m_{2}} & {m_{3}}\end{array}$$
#
# is unstable, since $$ is a blocking pair. However the matching
#
# $$\mu^{\prime}=\begin{array}{ll}{w_{1}} & {w_{2}} & {w_{3}} \\ {m_{1}} & {m_{3}} & {m_{2}}\end{array}$$
#
# is stable.

# %% [markdown]
# ## Some properties of stable matchings
#
# **Do stable matchings always exist?**
#
# We will demonstrate, however, that this problem does not arise. For any marriage market, no matter how many men and women are involved,and no matter what preferences they have, there will always be at least one matching that is stable. This is quite a surprising result, which turnsout to depend on both the two-sidedness of the market and the fact that matchings are one-to-one.
# 在特定的匹配结构下，稳定匹配总是存在的。
#
#
# **Example 2.5: The roommate problem (Gale and Shapley)**
